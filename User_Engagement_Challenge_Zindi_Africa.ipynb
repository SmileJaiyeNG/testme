# %% [markdown]
# ## This project is to predict the selected user from any cohort by consistency
#
# ### This to consider from the analysis
#     1. There is no assigned training set for this competition. The competitor is to create or assigned the training set.

# %%
# Import the libraries/packages.

import pandas as pd

# I will continue to add as the project progresses.

# %%
# Import the data for the analysis. 

competitions = pd.read_csv('User_Retention/Competition.csv')
blogs = pd.read_csv('User_Retention/Blogs.csv')
comments = pd.read_csv('User_Retention/Comments.csv')
competition_participation = pd.read_csv('User_Retention/CompetitionPartipation.csv')
discussion = pd.read_csv('User_Retention/Discussion.csv')
jobs = pd.read_csv('User_Retention/Jobs.csv')
sample_submission = pd.read_csv('User_Retention/SampleSubmission.csv')
user_activity = pd.read_csv('User_Retention/UserActivity.csv')
users = pd.read_csv('User_Retention/Users.csv')
variable_definitions = pd.read_csv('User_Retention/VariableDefinitions.csv')

# %%
competitions.
# Out:
# ['FeatureA',
#  'FeatureB',
#  'FeatureC',
#  'FeatureD',
#  'FeatureE',
#  'SecretCode',
#  'FeatureF',
#  'FeatureG',
#  'FeatureH',
#  'FeatureI',
#  'Country_ID',
#  'Comp_ID',
#  'End Time time',
#  'End Time Year',
#  'End Time Month',
#  'End Time Day_of_month',
#  'Start Time time',
#  'Start Time Year',
#  'Start Time Month',
#  'Start Time Day_of_month']

# %%
variable_definitions.head(60)
# Out:
#                          VariableName  \
# 0                            Comments
# 1                              UserID
# 2                    CommentDate Year
# 3                   CommentDate Month
# 4             CommentDate Day_of_week
# 5                                 NaN
# 6                        Competitions
# 7                             Country
# 8                            FeatureA
# 9                              CompID
# 10                           FeatureB
# 11                           FeatureC
# 12                               Kind
# 13                      Points Reward
# 14                           FeatureD
# 15                         SecretCode
# 16              SubmissionLimitPerDay
# 17                           FeatureE
# 18           CompEndTime Year
# 19          CompEndTime Month
# 20    CompEndTime Day_of_week
# 21         CompStartTime Year
# 22         CompStartTime Month
# 23  CompStartTime Day_of_week
# 24                                NaN
# ...

# %%
variable_definitions.iloc[52, 1]
# Out:
# 'A category the user falls into. This field is masked.'

# %% [markdown]
# ### Quality issues
# 1.

# %% [markdown]
# ### Tidiness Issues
# 1.
